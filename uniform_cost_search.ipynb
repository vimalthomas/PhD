# %%
Notebook for uniform cost search operation.

# %%
def uniform_cost_search(start, goal, graph, cost):
    
    answer = {}
    for node in goal:
        answer[node] = {'cost': float('inf'), 'path': []}
        
    # Initialize priority queue with start state and its cost to reach the next state
    pq = [(0, start, [])]
    
    # Initialize the dictionary to track the visited nodes
    visitedNode = {start: 0}

    while pq:
        # sort the priority query by the cost.
        pq.sort()
     
        curr_cost, curr_node, curr_path = pq.pop(0)

        
        if curr_node in goal:
            if curr_cost < answer[curr_node]['cost']:
                answer[curr_node]['cost'] = curr_cost
                answer[curr_node]['path'] = curr_path

        # Explore neighbors of the current node
        for neighbor in graph[curr_node]:
            
            cost_to_neighbor = curr_cost + cost[(curr_node, neighbor)]

            # If the neighbor has not been visited yet or the new cost is lower than the previously recorded cost
            if neighbor not in visitedNode or cost_to_neighbor < visitedNode[neighbor]:
               
                visitedNode[neighbor] = cost_to_neighbor
               
                pq.append((cost_to_neighbor, neighbor, curr_path + [neighbor]))

    return answer

 
# main function
if __name__ == '__main__':
     
    # create a graph with no more than 30 nodes
    graph, cost = [[] for i in range(30)], {}
 
    # add edges to the graph
    graph[0].append(4)
    graph[0].append(5)
    graph[0].append(16)
    graph[2].append(1)
    graph[3].append(1)
    graph[4].append(2)
    graph[4].append(3)
    graph[4].append(5)
    graph[5].append(8)
    graph[5].append(18)
    graph[6].append(3)
    graph[6].append(7)
    graph[8].append(16)
    graph[8].append(17)
    graph[16].append(17)
    graph[18].append(6)
    
 
    # add cost to each edge
    cost[(0, 4)] = 3
    cost[(0, 5)] = 9
    cost[(0, 16)] = 1
    cost[(2, 1)] = 2
    cost[(3, 1)] = 2
    cost[(4, 2)] = 1
    cost[(4, 3)] = 8
    cost[(4, 5)] = 2
    cost[(5, 8)] = 3
    cost[(5, 18)] = 2
    cost[(6, 3)] = 3
    cost[(6, 7)] = 2
    cost[(8, 16)] = 4
    cost[(8, 17)] = 4
    cost[(16, 17)] = 15
    cost[(18, 6)] = 1
    
    # set start state 
    start = 0
    
    # set goal state, there can be multiple goal states
    goal = [7]
    
    # call uniform_search_cost function to get the minimum cost to reach gaol. Bonus points for path
    # ****** You have to implement this function *****
    min_cost_info = uniform_cost_search(start, goal, graph, cost)
    #min_cost_info = 0
    #print("min_cost",min_cost_info)
    

    for node, info in min_cost_info.items():
        print(f'Minimum cost from {start} to {node} is {info["cost"]}')
      
    #   **** Bonus ****
        print(f'Path : {info["path"]}')
# Out:
# Minimum cost from 0 to 7 is 10
# Path : [4, 5, 18, 6, 7]
